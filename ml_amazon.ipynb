# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import time

# %%
ProductId=[]
UserId=[]
ProfileName=[]
HelpfulnessNumerator=[]
HelpfulnessDenominator=[]
Score=[]
Time=[]
ReviewSummary=[]
ReviewText=[]
for i in tqdm(range(1,568455)):
    with open(r'C:\Users\abhir\Downloads\txt_reviews\txt_reviews\review_{}.txt'.format(i),'r',encoding='utf8') as f:
        s=np.array(f.readlines())
        ProductId.append(s[0].split(':')[1].strip())
        UserId.append(s[1].split(':')[1].strip())
        ProfileName.append(s[2].split(':')[1].strip()) 
        HelpfulnessNumerator.append(s[3].split(':')[1].strip())
        HelpfulnessDenominator.append(s[4].split(':')[1].strip())
        Score.append(s[5].split(':')[1].strip())
        Time.append(s[6].split(':')[1].strip())
        ReviewSummary.append(s[7].split(':')[1].strip())
        ReviewText.append(s[8].split(':')[1].strip())
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 568454/568454 [03:50<00:00, 2470.92it/s]

# %%
df = pd.DataFrame({'Id':np.arange(1,len(ProductId)+1),'ProductId':ProductId,'UserId':UserId,'ProfileName':ProfileName,
                   'HelpfulnessNumerator':HelpfulnessNumerator,
                   'HelpfulnessDenominator':HelpfulnessDenominator,
                   'Time':Time,'ReviewSummary':ReviewSummary,'ReviewText':ReviewText,
                   'Score':Score
                  })

# %%
df.to_csv('amazon_food_reviw.csv')

# %%
df=pd.read_csv('amazon_food_reviw.csv')

# %%
df
# Out:
#         Unnamed: 0      Id   ProductId          UserId  \
# 0                0       1  B001E4KFG0  A3SGXH7AUHU8GW
# 1                1       2  B00813GRG4  A1D87F6ZCVE5NK
# 2                2       3  B000LQOCH0   ABXLMWJIXXAIN
# 3                3       4  B000UA0QIQ  A395BORC6FGVXV
# 4                4       5  B006K2ZZ7K  A1UQRSCLF8GW1T
# ...            ...     ...         ...             ...
# 568449      568449  568450  B001EO7N10  A28KG5XORO54AY
# 568450      568450  568451  B003S1WTCU  A3I8AFVPEE8KI5
# 568451      568451  568452  B004I613EE  A121AA1GQV751Z
# 568452      568452  568453  B004I613EE   A3IBEVCTXKNOH
# 568453      568453  568454  B001LR2CU2  A3LGQPJCZVL9UC
#
#                             ProfileName  HelpfulnessNumerator  \
# 0                            delmartian                     1
# 1                                dll pa                     0
# 2       Natalia Corres "Natalia Corres"                     1
# 3                                  Karl                     3
# 4         Michael D. Bigham "M. Wassir"                     0
# ...                                 ...                   ...
# 568449                 Lettie D. Carter                     0
# 568450                        R. Sawyer                     0
# 568451                    pksd "pk_007"                     2
# 568452          Kathy A. Welch "katwel"                     1
# 568453                         srfell17                     0
#
#         HelpfulnessDenominator        Time  \
# 0                            1  1303862400
# 1                            0  1346976000
# 2                            1  1219017600
# 3                            3  1307923200
# 4                            0  1350777600
# ...                        ...         ...
# 568449                       0  1299628800
# 568450                       0  1331251200
# 568451                       2  1329782400
# 568452                       1  1331596800
# 568453                       0  1338422400
#
#                              ReviewSummary  \
# 0                    Good Quality Dog Food
# 1                        Not as Advertised
# 2                    "Delight" says it all
# 3                           Cough Medicine
# 4                              Great taffy
# ...                                    ...
# 568449                 Will not do without
# 568450                        disappointed
# 568451            Perfect for our maltipoo
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                ReviewText  Score
# 0       I have bought several of the Vitality canned d...      5
# 1       Product arrived labeled as Jumbo Salted Peanut...      1
# 2       This is a confection that has been around a fe...      4
# 3       If you are looking for the secret ingredient i...      2
# 4       Great taffy at a great price.  There was a wid...      5
# ...                                                   ...    ...
# 568449  Great for sesame chicken..this is a good if no...      5
# 568450  I'm disappointed with the flavor. The chocolat...      2
# 568451  These stars are small, so you can give 10-15 o...      5
# 568452  These are the BEST treats for training and rew...      5
# 568453  I am very satisfied ,product is as advertised,...      5
#
# [568454 rows x 11 columns]
